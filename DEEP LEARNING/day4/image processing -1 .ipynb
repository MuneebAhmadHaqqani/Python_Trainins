# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as im

# %% [markdown]
# ### creating a photo using numpy array

# %%
image =[[0,255,0,255],
        [255,0,255,0],
        [0,255,0,255],
        [255,0,255,0]]

# %%
arr_image=np.array(image)
arr_image
# Out:
# array([[  0, 255,   0, 255],
#        [255,   0, 255,   0],
#        [  0, 255,   0, 255],
#        [255,   0, 255,   0]])

# %%
arr_image.shape
# Out:
# (4, 4)

# %% [markdown]
# ### showing the photo created by numpy

# %%
plt.imshow(arr_image,cmap="gray")

# %% [markdown]
# ### Task : craete a photo using numpy array to show your first name letter

# %% [markdown]
# ### loading and reading image

# %%
img=im.imread(r"C:\Users\etisalat\Pictures\04september-1.jpg") # loading the image

# %%
img.shape
# Out:
# (750, 600, 3)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### crop the image

# %% [markdown]
# ### task: use slicing to extract the eyes only

# %%
plt.imshow(img[:100,:100])

# %%
plt.imshow(img[300:400,200:450])

# %% [markdown]
# ### apply noise to the image

# %% [markdown]
# ### task create a noise photo using random function

# %%
n_img=np.random.randint(0,255,(750, 600, 3))

# %%
plt.imshow(n_img)

# %% [markdown]
# ### mix the noise image with john Maccharthy image

# %%
f=img+(n_img*0.1)
plt.imshow(f.astype("uint8"))
plt.show()
