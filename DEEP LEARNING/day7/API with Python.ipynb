# %%
import requests

# %%
json_input={"sepal_length":5.1,
            "sepal_width":3.5,
            "petal_length":1.4,
            "petal_width":0.2}

# %%
r=requests.post("http://127.0.0.1:5000/api/flower",json=json_input)

# %%
r.status_code
# Out:
# 200

# %%
print(r.text)
# Out:
# "0"
