# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\etisalat\Downloads\titanic.csv")
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.head()
# Out:
#    Id  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# Id          891 non-null int64
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.isnull().sum()
# Out:
# Id            0
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data.dtypes
# Out:
# Id            int64
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
data.head()
# Out:
#    Id  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### get the name for all passengers with Age>35

# %%
data[data["Age"]>35][["Name","Age"]]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 6                              McCarthy, Mr. Timothy J  54.0
# 11                            Bonnell, Miss. Elizabeth  58.0
# 13                         Andersson, Mr. Anders Johan  39.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0
# 30                            Uruchurtu, Don. Manuel E  40.0
# 33                               Wheadon, Mr. Edward H  66.0
# 35                      Holverson, Mr. Alexander Oskar  42.0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0
# 54                      Ostby, Mr. Engelhart Cornelius  65.0
# 61                                 Icard, Miss. Amelie  38.0
# 62                         Harris, Mr. Henry Birkhardt  45.0
# ...

# %% [markdown]
# ### get all rows for Pclass=2 or 3

# %%
data[(data["Pclass"]==2) | (data["Pclass"]==3)]
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 2      3         1       3                             Heikkinen, Miss. Laina
# 4      5         0       3                           Allen, Mr. William Henry
# 5      6         0       3                                   Moran, Mr. James
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# 12    13         0       3                     Saundercock, Mr. William Henry
# 13    14         0       3                        Andersson, Mr. Anders Johan
# 14    15         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# ...

# %% [markdown]
# ### assign values

# %%
data.head()
# Out:
#    Id  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
data.iloc[1,3]="Mohammed Marwan"

# %%
data.head()
# Out:
#    Id  Survived  Pclass                                          Name     Sex  \
# 0   1         0       3                       Braund, Mr. Owen Harris    male
# 1   2         1       1                               Mohammed Marwan  female
# 2   3         1       3                        Heikkinen, Miss. Laina  female
# 3   4         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4   5         0       3                      Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  38.0      1      0          PC 17599  71.2833   C85        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  35.0      1      0            113803  53.1000  C123        S
# 4  35.0      0      0            373450   8.0500   NaN        S

# %%
data.iloc[2:5,3]="Ahmad"

# %%
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 3      4         1       1                                              Ahmad
# 4      5         0       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %% [markdown]
# ### replacing "female" with "f"

# %%
data.iloc[:,4][data["Sex"]=="female"]="f"
# Out:
# C:\Users\etisalat\anacondanew\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 3      4         1       1                                              Ahmad
# 4      5         0       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
data["Fare"]*3
# Out:
# 0       21.7500
# 1      213.8499
# 2       23.7750
# 3      159.3000
# 4       24.1500
# 5       25.3749
# 6      155.5875
# 7       63.2250
# 8       33.3999
# 9       90.2124
# 10      50.1000
# 11      79.6500
# 12      24.1500
# 13      93.8250
# 14      23.5626
# 15      48.0000
# 16      87.3750
# 17      39.0000
# 18      54.0000
# 19      21.6750
# 20      78.0000
# 21      39.0000
# 22      24.0876
# 23     106.5000
# 24      63.2250
# 25      94.1625
# 26      21.6750
# 27     789.0000
# 28      23.6376
# 29      23.6874
#          ...
# 861     34.5000
# 862     77.7876
# 863    208.6500
# 864     39.0000
# 865     39.0000
# 866     41.5749
# 867    151.4874
# 868     28.5000
# 869     33.3999
# 870     23.6874
# 871    157.6626
# 872     15.0000
# 873     27.0000
# 874     72.0000
# 875     21.6750
# 876     29.5374
# 877     23.6874
# 878     23.6874
# 879    249.4749
# 880     78.0000
# 881     23.6874
# 882     31.5501
# 883     31.5000
# 884     21.1500
# ...

# %%
data["Fare"]=data["Fare"]*3

# %%
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 3      4         1       1                                              Ahmad
# 4      5         0       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.drop_duplicates(subset="Name",inplace=True)

# %%
data.shape
# Out:
# (889, 12)

# %%
data.head()
# Out:
#    Id  Survived  Pclass                     Name   Sex   Age  SibSp  Parch  \
# 0   1         0       3  Braund, Mr. Owen Harris  male  22.0      1      0
# 1   2         1       1          Mohammed Marwan     f  38.0      1      0
# 2   3         1       3                    Ahmad     f  26.0      0      0
# 5   6         0       3         Moran, Mr. James  male   NaN      0      0
# 6   7         0       1  McCarthy, Mr. Timothy J  male  54.0      0      0
#
#              Ticket      Fare Cabin Embarked
# 0         A/5 21171   21.7500   NaN        S
# 1          PC 17599  213.8499   C85        C
# 2  STON/O2. 3101282   23.7750   NaN        S
# 5            330877   25.3749   NaN        Q
# 6             17463  155.5875   E46        S

# %% [markdown]
# ### creating new column

# %%
data["new column"]=""

# %%
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# 11    12         1       1                           Bonnell, Miss. Elizabeth
# 12    13         0       3                     Saundercock, Mr. William Henry
# ...

# %%
data["new column"]=data["Fare"]*5

# %%
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# 11    12         1       1                           Bonnell, Miss. Elizabeth
# 12    13         0       3                     Saundercock, Mr. William Henry
# ...

# %%
data.columns
# Out:
# Index(['Id', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'new column'],
#       dtype='object')

# %%
data.rename(columns={"Id":"ID","Survived":"SURVIVED"},inplace=True)

# %%
data
# Out:
#       ID  SURVIVED  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# 11    12         1       1                           Bonnell, Miss. Elizabeth
# 12    13         0       3                     Saundercock, Mr. William Henry
# ...

# %%
data.rename(columns=str.upper)
# Out:
#       ID  SURVIVED  PCLASS                                               NAME  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1                                    Mohammed Marwan
# 2      3         1       3                                              Ahmad
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# 11    12         1       1                           Bonnell, Miss. Elizabeth
# 12    13         0       3                     Saundercock, Mr. William Henry
# ...

# %% [markdown]
# ### groupby

# %%
data[["Sex","Age"]].groupby("Sex").mean()
# Out:
#             Age
# Sex
# f     27.888462
# male  30.717190

# %%
data.groupby("SURVIVED").count()
# Out:
#            ID  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# SURVIVED
# 0         548     548   548  548  423    548    548     548   548     68
# 1         341     341   341  341  289    341    341     341   341    135
#
#           Embarked  new column
# SURVIVED
# 0              548         548
# 1              339         341

# %%
data[["Sex","Age"]].groupby("Sex").count()
# Out:
#       Age
# Sex
# f     260
# male  452

# %%
data[["Sex","Age"]].groupby("Sex").max()
# Out:
#        Age
# Sex
# f     63.0
# male  80.0

# %%
data.groupby("Sex").mean()
# Out:
#               ID  SURVIVED    Pclass        Age     SibSp     Parch  \
# Sex
# f     432.392971  0.741214  2.162939  27.888462  0.693291  0.651757
# male  454.927083  0.189236  2.388889  30.717190  0.430556  0.236111
#
#             Fare  new column
# Sex
# f     133.356832  666.784160
# male   76.662690  383.313451

# %%
data.groupby("Sex")["Age"].mean()
# Out:
# Sex
# f       27.888462
# male    30.717190
# Name: Age, dtype: float64

# %%
data.groupby("Sex").count()
# Out:
#        ID  SURVIVED  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Sex
# f     313       313     313   313  260    313    313     313   313     96
# male  576       576     576   576  452    576    576     576   576    107
#
#       Embarked  new column
# Sex
# f          311         313
# male       576         576

# %% [markdown]
# ### groupby based on two columns

# %%
data.groupby(["SURVIVED","Sex"]).count()
# Out:
#                 ID  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# SURVIVED Sex
# 0        f      81      81    81   64     81     81      81    81      6
#          male  467     467   467  359    467    467     467   467     62
# 1        f     232     232   232  196    232    232     232   232     90
#          male  109     109   109   93    109    109     109   109     45
#
#                Embarked  new column
# SURVIVED Sex
# 0        f           81          81
#          male       467         467
# 1        f          230         232
#          male       109         109

# %%
data.head()
# Out:
#    ID  SURVIVED  Pclass                     Name   Sex   Age  SibSp  Parch  \
# 0   1         0       3  Braund, Mr. Owen Harris  male  22.0      1      0
# 1   2         1       1          Mohammed Marwan     f  38.0      1      0
# 2   3         1       3                    Ahmad     f  26.0      0      0
# 5   6         0       3         Moran, Mr. James  male   NaN      0      0
# 6   7         0       1  McCarthy, Mr. Timothy J  male  54.0      0      0
#
#              Ticket      Fare Cabin Embarked  new column
# 0         A/5 21171   21.7500   NaN        S    108.7500
# 1          PC 17599  213.8499   C85        C   1069.2495
# 2  STON/O2. 3101282   23.7750   NaN        S    118.8750
# 5            330877   25.3749   NaN        Q    126.8745
# 6             17463  155.5875   E46        S    777.9375

# %% [markdown]
# ### Label Encoder

# %%
import sklearn.preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
data["Sex"]=encoder.fit_transform(data["Sex"])

# %%
data
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# 5      6         0       3                                   Moran, Mr. James
# 6      7         0       1                            McCarthy, Mr. Timothy J
# 7      8         0       3                     Palsson, Master. Gosta Leonard
# 8      9         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11         1       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %% [markdown]
# ### Example

# %%
data2=pd.DataFrame({"c":["UAE","KSA","UAE","OMAN","UAE","QATAR","KSA"]})

# %%
data2
# Out:
#        c
# 0    UAE
# 1    KSA
# 2    UAE
# 3   OMAN
# 4    UAE
# 5  QATAR
# 6    KSA

# %%
encoder=LabelEncoder()
data2["c"]=encoder.fit_transform(data2["c"])

# %%
data2
# Out:
#    c
# 0  3
# 1  0
# 2  3
# 3  1
# 4  3
# 5  2
# 6  0

# %% [markdown]
# ### remove a certain column from the data frame

# %%
data.drop(columns="Name",inplace=True)

# %%
data.head()
# Out:
#    Id  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0   1         0       3    1  22.0      1      0         A/5 21171   7.2500
# 1   2         1       1    0  38.0      1      0          PC 17599  71.2833
# 2   3         1       3    0  26.0      0      0  STON/O2. 3101282   7.9250
# 3   4         1       1    0  35.0      1      0            113803  53.1000
# 4   5         0       3    1  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %% [markdown]
# ### Normalization

# %%
data3=pd.DataFrame({"sales":[3000,5000,2000,2400,5000,1000,1500],
                    "Age":[20,30,40,35,45,55,60],
                   "Gender":[1,1,0,1,0,1,1],
                   "Salary":[20000,15000,30000,5000,25000,30000,22000]})

# %%
data3
# Out:
#    sales  Age  Gender  Salary
# 0   3000   20       1   20000
# 1   5000   30       1   15000
# 2   2000   40       0   30000
# 3   2400   35       1    5000
# 4   5000   45       0   25000
# 5   1000   55       1   30000
# 6   1500   60       1   22000

# %%
x=data3.iloc[:,:3]

# %%
x
# Out:
#    sales  Age  Gender
# 0   3000   20       1
# 1   5000   30       1
# 2   2000   40       0
# 3   2400   35       1
# 4   5000   45       0
# 5   1000   55       1
# 6   1500   60       1

# %%
y=data3.iloc[:,3]
y
# Out:
# 0    20000
# 1    15000
# 2    30000
# 3     5000
# 4    25000
# 5    30000
# 6    22000
# Name: Salary, dtype: int64

# %%
data3.shape
# Out:
# (7, 4)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# C:\Users\etisalat\anacondanew\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# array([[0.5  , 0.   , 1.   ],
#        [1.   , 0.25 , 1.   ],
#        [0.25 , 0.5  , 0.   ],
#        [0.35 , 0.375, 1.   ],
#        [1.   , 0.625, 0.   ],
#        [0.   , 0.875, 1.   ],
#        [0.125, 1.   , 1.   ]])

# %% [markdown]
# ### spliting the data into (training) & (Testing)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain
# Out:
#    sales  Age  Gender
# 2   2000   40       0
# 6   1500   60       1
# 3   2400   35       1
# 5   1000   55       1

# %%
xtest
# Out:
#    sales  Age  Gender
# 4   5000   45       0
# 0   3000   20       1
# 1   5000   30       1

# %%
ytrain
# Out:
# 2    30000
# 6    22000
# 3     5000
# 5    30000
# Name: Salary, dtype: int64

# %%
ytest
# Out:
# 4    25000
# 0    20000
# 1    15000
# Name: Salary, dtype: int64
