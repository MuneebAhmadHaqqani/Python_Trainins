# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### load a file/dataset

# %%
data=pd.read_csv(r"C:\Users\etisalat\Data Science\Pandas\datawh_missing.csv")

# %%
data
# Out:
#          Dates Temperature Humidity Pressure Air Quality
# 0   30-04-2018         218      182        4           2
# 1   01-05-2018           ?      182        3           2
# 2   02-05-2018           .      439      NaN           0
# 3   03-05-2018        2439       53        5           1
# 4   04-05-2018         824      444        5         NaN
# 5   05-05-2018        1744        .        5           1
# 6   06-05-2018         786        .        5           1
# 7   07-05-2018        1326      309        .           1
# 8   08-05-2018        1804      188        .           2
# 9   09-05-2018           ?      420        0           1
# 10  10-05-2018        2524      433        1           0
# 11  11-05-2018        2945      149        .           0
# 12  12-05-2018           .      531        1           1
# 13  13-05-2018        1318      360        3           2
# 14  14-05-2018           .      435      NaN           2
# ...

# %%
data.head()
# Out:
#         Dates Temperature Humidity Pressure Air Quality
# 0  30-04-2018         218      182        4           2
# 1  01-05-2018           ?      182        3           2
# 2  02-05-2018           .      439      NaN           0
# 3  03-05-2018        2439       53        5           1
# 4  04-05-2018         824      444        5         NaN

# %% [markdown]
# ### to get the shape (num of rows and columns)

# %%
data.shape
# Out:
# (20, 5)

# %% [markdown]
# ### to get the columns header names

# %%
data.columns
# Out:
# Index(['Dates', 'Temperature', 'Humidity', 'Pressure', 'Air Quality'], dtype='object')

# %%
data=pd.read_csv(r"C:\Users\etisalat\Data Science\Pandas\datawh_missing.csv",na_values=["?","."])

# %%
data
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018        218.0     182.0       4.0          2.0
# 1   01-05-2018          NaN     182.0       3.0          2.0
# 2   02-05-2018          NaN     439.0       NaN          0.0
# 3   03-05-2018       2439.0      53.0       5.0          1.0
# 4   04-05-2018        824.0     444.0       5.0          NaN
# 5   05-05-2018       1744.0       NaN       5.0          1.0
# 6   06-05-2018        786.0       NaN       5.0          1.0
# 7   07-05-2018       1326.0     309.0       NaN          1.0
# 8   08-05-2018       1804.0     188.0       NaN          2.0
# 9   09-05-2018          NaN     420.0       0.0          1.0
# 10  10-05-2018       2524.0     433.0       1.0          0.0
# 11  11-05-2018       2945.0     149.0       NaN          0.0
# 12  12-05-2018          NaN     531.0       1.0          1.0
# 13  13-05-2018       1318.0     360.0       3.0          2.0
# ...

# %% [markdown]
# ### handle missing values

# %% [markdown]
# ### .isnull()

# %%
data.isnull().sum()
# Out:
# Dates          0
# Temperature    7
# Humidity       3
# Pressure       7
# Air Quality    2
# dtype: int64

# %% [markdown]
# ### to remove all rows with missing values we use : .dropna()

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018        218.0     182.0       4.0          2.0
# 3   03-05-2018       2439.0      53.0       5.0          1.0
# 10  10-05-2018       2524.0     433.0       1.0          0.0
# 13  13-05-2018       1318.0     360.0       3.0          2.0
# 17  17-05-2018       2200.0     325.0       3.0          2.0
# 19  19-05-2018        766.0     535.0       3.0          2.0

# %%
data2=pd.read_csv(r"C:\Users\etisalat\Data Science\Pandas\datawh_missing.csv",na_values=["?","."])

# %%
data2
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018        218.0     182.0       4.0          2.0
# 1   01-05-2018          NaN     182.0       3.0          2.0
# 2   02-05-2018          NaN     439.0       NaN          0.0
# 3   03-05-2018       2439.0      53.0       5.0          1.0
# 4   04-05-2018        824.0     444.0       5.0          NaN
# 5   05-05-2018       1744.0       NaN       5.0          1.0
# 6   06-05-2018        786.0       NaN       5.0          1.0
# 7   07-05-2018       1326.0     309.0       NaN          1.0
# 8   08-05-2018       1804.0     188.0       NaN          2.0
# 9   09-05-2018          NaN     420.0       0.0          1.0
# 10  10-05-2018       2524.0     433.0       1.0          0.0
# 11  11-05-2018       2945.0     149.0       NaN          0.0
# 12  12-05-2018          NaN     531.0       1.0          1.0
# 13  13-05-2018       1318.0     360.0       3.0          2.0
# ...

# %%
data2.dropna(thresh=4)
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018        218.0     182.0       4.0          2.0
# 1   01-05-2018          NaN     182.0       3.0          2.0
# 3   03-05-2018       2439.0      53.0       5.0          1.0
# 4   04-05-2018        824.0     444.0       5.0          NaN
# 5   05-05-2018       1744.0       NaN       5.0          1.0
# 6   06-05-2018        786.0       NaN       5.0          1.0
# 7   07-05-2018       1326.0     309.0       NaN          1.0
# 8   08-05-2018       1804.0     188.0       NaN          2.0
# 9   09-05-2018          NaN     420.0       0.0          1.0
# 10  10-05-2018       2524.0     433.0       1.0          0.0
# 11  11-05-2018       2945.0     149.0       NaN          0.0
# 12  12-05-2018          NaN     531.0       1.0          1.0
# 13  13-05-2018       1318.0     360.0       3.0          2.0
# 15  15-05-2018          NaN     259.0       4.0          0.0
# ...

# %% [markdown]
# ### fill missing Values

# %%
round(data2["Temperature"].mean(),1)
# Out:
# 1585.8

# %%
data2["Temperature"].fillna(round(data2["Temperature"].mean(),1),inplace=True)

# %%
data2
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018        218.0     182.0       4.0          2.0
# 1   01-05-2018       1585.8     182.0       3.0          2.0
# 2   02-05-2018       1585.8     439.0       NaN          0.0
# 3   03-05-2018       2439.0      53.0       5.0          1.0
# 4   04-05-2018        824.0     444.0       5.0          NaN
# 5   05-05-2018       1744.0       NaN       5.0          1.0
# 6   06-05-2018        786.0       NaN       5.0          1.0
# 7   07-05-2018       1326.0     309.0       NaN          1.0
# 8   08-05-2018       1804.0     188.0       NaN          2.0
# 9   09-05-2018       1585.8     420.0       0.0          1.0
# 10  10-05-2018       2524.0     433.0       1.0          0.0
# 11  11-05-2018       2945.0     149.0       NaN          0.0
# 12  12-05-2018       1585.8     531.0       1.0          1.0
# 13  13-05-2018       1318.0     360.0       3.0          2.0
# ...

# %%
data2.describe()
# Out:
#        Temperature    Humidity   Pressure  Air Quality
# count    20.000000   20.000000  20.000000    20.000000
# mean   1585.846154  339.235294   3.230769     1.222222
# std     641.798693  136.247657   1.343751     0.764719
# min     218.000000   53.000000   0.000000     0.000000
# 25%    1324.000000  241.250000   3.000000     1.000000
# 50%    1585.846154  339.235294   3.230769     1.111111
# 75%    1759.000000  436.000000   4.000000     2.000000
# max    2945.000000  535.000000   5.000000     2.000000

# %%
data2.mean()
# Out:
# Temperature    1585.846154
# Humidity        339.235294
# Pressure          3.230769
# Air Quality       1.222222
# dtype: float64

# %%
data2.fillna(round(data2.mean(),1),inplace=True)

# %%
data2
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018        218.0     182.0       4.0          2.0
# 1   01-05-2018       1585.8     182.0       3.0          2.0
# 2   02-05-2018       1585.8     439.0       3.2          0.0
# 3   03-05-2018       2439.0      53.0       5.0          1.0
# 4   04-05-2018        824.0     444.0       5.0          1.2
# 5   05-05-2018       1744.0     339.2       5.0          1.0
# 6   06-05-2018        786.0     339.2       5.0          1.0
# 7   07-05-2018       1326.0     309.0       3.2          1.0
# 8   08-05-2018       1804.0     188.0       3.2          2.0
# 9   09-05-2018       1585.8     420.0       0.0          1.0
# 10  10-05-2018       2524.0     433.0       1.0          0.0
# 11  11-05-2018       2945.0     149.0       3.2          0.0
# 12  12-05-2018       1585.8     531.0       1.0          1.0
# 13  13-05-2018       1318.0     360.0       3.0          2.0
# ...

# %%
data3=pd.read_csv(r"C:\Users\etisalat\Data Science\Pandas\datawh_missing2.csv",na_values=["?","."])

# %%
data3
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality  test
# 0   30-04-2018        218.0     182.0       4.0          2.0  pass
# 1     1/5/2018          NaN     182.0       3.0          2.0  fail
# 2     2/5/2018          NaN     439.0       NaN          0.0  pass
# 3     3/5/2018       2439.0      53.0       5.0          1.0  pass
# 4     4/5/2018        824.0     444.0       5.0          NaN  pass
# 5     5/5/2018       1744.0       NaN       5.0          1.0  fail
# 6     6/5/2018        786.0       NaN       5.0          1.0  pass
# 7     7/5/2018       1326.0     309.0       NaN          1.0   NaN
# 8     8/5/2018       1804.0     188.0       NaN          2.0  pass
# 9     9/5/2018          NaN     420.0       0.0          1.0  fail
# 10   10/5/2018       2524.0     433.0       1.0          0.0  fail
# 11   11/5/2018       2945.0     149.0       NaN          0.0  pass
# 12   12/5/2018          NaN     531.0       1.0          1.0  pass
# ...

# %%
data3.fillna(round(data3.mean(),1),inplace=True)

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
# Dates          20 non-null object
# Temperature    20 non-null float64
# Humidity       20 non-null float64
# Pressure       20 non-null float64
# Air Quality    20 non-null float64
# test           17 non-null object
# dtypes: float64(4), object(2)
# memory usage: 1.0+ KB

# %%
data3.isnull().sum()
# Out:
# Dates          0
# Temperature    0
# Humidity       0
# Pressure       0
# Air Quality    0
# test           3
# dtype: int64

# %%
data3
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality  test
# 0   30-04-2018        218.0     182.0       4.0          2.0  pass
# 1     1/5/2018       1585.8     182.0       3.0          2.0  fail
# 2     2/5/2018       1585.8     439.0       3.2          0.0  pass
# 3     3/5/2018       2439.0      53.0       5.0          1.0  pass
# 4     4/5/2018        824.0     444.0       5.0          1.2  pass
# 5     5/5/2018       1744.0     339.2       5.0          1.0  fail
# 6     6/5/2018        786.0     339.2       5.0          1.0  pass
# 7     7/5/2018       1326.0     309.0       3.2          1.0   NaN
# 8     8/5/2018       1804.0     188.0       3.2          2.0  pass
# 9     9/5/2018       1585.8     420.0       0.0          1.0  fail
# 10   10/5/2018       2524.0     433.0       1.0          0.0  fail
# 11   11/5/2018       2945.0     149.0       3.2          0.0  pass
# 12   12/5/2018       1585.8     531.0       1.0          1.0  pass
# ...

# %%
data3["test"].mode()
# Out:
# 0    pass
# dtype: object

# %%
data3.fillna(data3["test"].mode()[0],inplace=True)

# %%
data3
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality  test
# 0   30-04-2018        218.0     182.0       4.0          2.0  pass
# 1     1/5/2018       1585.8     182.0       3.0          2.0  fail
# 2     2/5/2018       1585.8     439.0       3.2          0.0  pass
# 3     3/5/2018       2439.0      53.0       5.0          1.0  pass
# 4     4/5/2018        824.0     444.0       5.0          1.2  pass
# 5     5/5/2018       1744.0     339.2       5.0          1.0  fail
# 6     6/5/2018        786.0     339.2       5.0          1.0  pass
# 7     7/5/2018       1326.0     309.0       3.2          1.0  pass
# 8     8/5/2018       1804.0     188.0       3.2          2.0  pass
# 9     9/5/2018       1585.8     420.0       0.0          1.0  fail
# 10   10/5/2018       2524.0     433.0       1.0          0.0  fail
# 11   11/5/2018       2945.0     149.0       3.2          0.0  pass
# 12   12/5/2018       1585.8     531.0       1.0          1.0  pass
# ...

# %%
data3.isnull().sum()
# Out:
# Dates          0
# Temperature    0
# Humidity       0
# Pressure       0
# Air Quality    0
# test           0
# dtype: int64
